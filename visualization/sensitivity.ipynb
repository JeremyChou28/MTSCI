stationary_mapes_point_ood=[2.227,2.313,2.410,2.664,2.946,3.326,3.724,4.462,6.778]
# TimesNet
timesnet_maes_point_ood=[5.848,5.864,5.875,6.091,6.361,6.759,7.130,8.030,11.563,]
timesnet_rmses_point_ood=[26.056,26.673,26.842,28.261,29.624,31.662,33.070,37.217,49.142,]
timesnet_mapes_point_ood=[3.465,3.461,3.453,3.591,3.755,3.996,4.228,4.774,6.898,]
# SAITS
saits_maes_point_ood=[3.682,4.079,4.778,5.928,7.883,10.951,16.377,26.074,48.845,]
saits_rmses_point_ood=[19.085,19.412,20.870,23.835,28.753,36.244,49.062,72.211,124.420,]
saits_mapes_point_ood=[2.189,2.419,2.818,3.503,4.666,6.493,9.738,15.540,29.185]

colors=sns.color_palette()

# 创建两个子图，2行1列
fig, ax = plt.subplots(1, 2, figsize=(30, 10))
x_values=np.array([0,5,10,15,20,25,30,35,40])
miss_rates=['10%','20%','30%','40%','50%','60%','70%','80%','90%']

ax[0].tick_params(axis='x', labelsize=40)
ax[0].tick_params(axis='y', labelsize=40)
ax[1].tick_params(axis='x', labelsize=40)
ax[1].tick_params(axis='y', labelsize=40)

# 在第一个子图中绘制6条曲线
ax[0].plot(x_values, ours_maes_point_iid, '-o',label='ours',color=colors[0],linewidth=8,markersize=20)
ax[0].plot(x_values, csdi_maes_point_iid, '-o',label='CSDI',color=colors[1],linewidth=8,markersize=20)
ax[0].plot(x_values, csbi_maes_point_iid, '-o',label='CSBI',color=colors[2],linewidth=8,markersize=20)
ax[0].plot(x_values, saits_maes_point_iid, '-o',label='SAITS',color=colors[3],linewidth=8,markersize=20)
ax[0].plot(x_values, stationary_maes_point_iid, '-o',label='Non-stationary',color=colors[4],linewidth=8,markersize=20)
ax[0].plot(x_values, timesnet_maes_point_iid, '-o',label='TimesNet',color=colors[5],linewidth=8,markersize=20)

ax[0].set_ylabel('MAE',fontsize=60)
ax[0].set_ylim(1.90, 15.00)
ax[0].set_xticks(x_values, miss_rates,fontsize=40)
ax[0].set_title('Point Missing',fontsize=60)
ax[0].legend(loc='upper left', ncols=1, fontsize=40,handlelength=1, edgecolor='black')
ax[0].grid(linestyle='dashed')

# 在第二个子图中绘制6条曲线
ax[1].plot(x_values, ours_maes_point_ood, '-o',label='ours',color=colors[0],linewidth=8,markersize=20)
ax[1].plot(x_values, csdi_maes_point_ood, '-o',label='CSDI',color=colors[1],linewidth=8,markersize=20)
ax[1].plot(x_values, csbi_maes_point_ood, '-o',label='CSBI',color=colors[2],linewidth=8,markersize=20)
ax[1].plot(x_values, saits_maes_point_ood, '-o',label='SAITS',color=colors[3],linewidth=8,markersize=20)
ax[1].plot(x_values, stationary_maes_point_ood, '-o',label='Non-stationary',color=colors[4],linewidth=8,markersize=20)
ax[1].plot(x_values, timesnet_maes_point_ood, '-o',label='TimesNet',color=colors[5],linewidth=8,markersize=20)

ax[1].set_ylabel('MAE',fontsize=60)
ax[1].set_ylim(1.90, 50.00)
ax[1].set_xticks(x_values, miss_rates,fontsize=40)
ax[1].set_title('Block Missing',fontsize=60)
ax[1].legend(loc='upper left', ncols=1, fontsize=40,handlelength=1, edgecolor='black')
ax[1].grid(linestyle='dashed')

# 调整子图之间的间距
# plt.tight_layout()

# 显示图形
plt.savefig('../img/sens_Weather.pdf',dpi=300,bbox_inches='tight')
plt.savefig('../img/sens_Weather.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# Ours vs CSDI

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import seaborn as sns

matplotlib.rcParams['pdf.fonttype']=42
matplotlib.rcParams['ps.fonttype']=42
plt.rcParams['font.sans-serif'] = ['Times New Roman']

# iid
# ours
ours_maes_point_iid=[2.038,1.935,1.939,2.071,2.290,2.456,2.751,3.355,4.566]
ours_rmses_point_iid=[16.995,15.992,15.591,16.610,18.306,18.959,19.854,23.616,28.487]
ours_mapes_point_iid=[1.212,1.147,1.143,1.224,1.355,1.456,1.636,2.000,2.728]
# CSDI
csdi_maes_point_iid=[2.187,2.063,2.036,2.132,2.310,2.503,2.777,3.391,4.589]
csdi_rmses_point_iid=[15.701,15.301,14.821,15.330,16.388,17.078,18.057,21.113,29.021]
csdi_mapes_point_iid=[1.304,1.225,1.201,1.260,1.367,1.484,1.650,2.019,2.796]

# ood
# ours
ours_maes_point_ood=[1.995,1.942,1.962,2.180,2.474,2.842,3.546,5.760,13.046]
ours_rmses_point_ood=[16.831,16.007,15.711,16.805,18.417,19.771,21.286,28.048,43.728]
ours_mapes_point_ood=[1.186,1.151,1.157,1.289,1.464,1.685,2.109,3.433,7.795]
# CSDI
csdi_maes_point_ood=[2.123,2.067,2.077,2.285,2.569,3.033,4.460,11.394,34.830]
csdi_rmses_point_ood=[15.524,15.402,14.952,15.642,16.923,18.573,24.214,54.287,121.000]
csdi_mapes_point_ood=[1.265,1.227,1.225,1.350,1.520,1.796,2.647,6.800,20.900]

colors=sns.color_palette()

# 创建两个子图，2行1列
fig, ax = plt.subplots(1, 2, figsize=(30, 10))
x_values=np.array([0,5,10,15,20,25,30,35,40])
miss_rates=['10%','20%','30%','40%','50%','60%','70%','80%','90%']

ax[0].tick_params(axis='x', labelsize=40)
ax[0].tick_params(axis='y', labelsize=40)
ax[1].tick_params(axis='x', labelsize=40)
ax[1].tick_params(axis='y', labelsize=40)

# 在第一个子图中绘制6条曲线
ax[0].plot(x_values, ours_rmses_point_iid, '-o',label='ours',color=colors[0],linewidth=8,markersize=20)
ax[0].plot(x_values, csdi_rmses_point_iid, '-o',label='CSDI',color=colors[1],linewidth=8,markersize=20)

ax[0].set_ylabel('MAE',fontsize=60)
# ax[0].set_ylim(1.90, 5.00)
ax[0].set_xticks(x_values, miss_rates,fontsize=40)
ax[0].set_title('Independent and identically distributed',fontsize=60)
ax[0].legend(loc='upper left', ncols=1, fontsize=40,handlelength=1, edgecolor='black')
ax[0].grid(linestyle='dashed')

# 在第二个子图中绘制6条曲线
ax[1].plot(x_values, ours_rmses_point_ood, '-o',label='ours',color=colors[0],linewidth=8,markersize=20)
ax[1].plot(x_values, csdi_rmses_point_ood, '-o',label='CSDI',color=colors[1],linewidth=8,markersize=20)

ax[1].set_ylabel('MAE',fontsize=60)
# ax[1].set_ylim(1.90, 36.00)
ax[1].set_xticks(x_values, miss_rates,fontsize=40)
ax[1].set_title('Out of distribution',fontsize=60)
ax[1].legend(loc='upper left', ncols=1, fontsize=40,handlelength=1, edgecolor='black')
ax[1].grid(linestyle='dashed')

# 调整子图之间的间距
# plt.tight_layout()

# 显示图形
plt.savefig('../img/sens_Weather.pdf',dpi=300,bbox_inches='tight')
plt.savefig('../img/sens_Weather.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped
