# %% [markdown]
# Point Missing on ETTm1

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib

matplotlib.rcParams['pdf.fonttype']=42
matplotlib.rcParams['ps.fonttype']=42
plt.rcParams['font.sans-serif'] = ['Times New Roman']

# point missing
hidden_size=[16,32,64,128]
ETTm1_hd_maes=[0.23,0.227,0.214,0.218]
ETTm1_hd_rmses=[0.386,0.417,0.358,0.363]
ETTm1_hd_mapes=[2.908,2.867,2.711,2.756]
layers=[1,2,3,4]
ETTm1_layer_maes=[0.253,0.247,0.23,0.214]
ETTm1_layer_rmses=[0.412,0.438,0.396,0.358]
ETTm1_layer_mapes=[3.194,3.124,2.901,2.711]
beta_end=[0.1,0.2,0.3,0.4]
ETTm1_beta_maes=[0.233,0.214,0.22,0.226]
ETTm1_beta_rmses=[0.414,0.358,0.370,0.412]
ETTm1_beta_mapes=[2.947,2.711,2.786,2.861]
loss_weights=[0.5,1,2,5,10]
ETTm1_lw_maes=[0.232,0.219,0.226,0.214,0.220]
ETTm1_lw_rmses=[0.407,0.370,0.388,0.358,0.366]
ETTm1_lw_mapes=[2.931,2.766,2.853,2.711,2.774]

fig, ax = plt.subplots(1,4,figsize=(34,6))

color1='#0076B9'
color2='#FF8C00'

# hidden dimension
line1,=ax[0].plot(hidden_size, ETTm1_hd_rmses, markersize='20',color=color1, linestyle='-',linewidth=6, marker='s',label='RMSE', zorder=1)
ax[0].set_xlabel('Size of hidden dimension',fontsize=42)
ax[0].set_ylabel('RMSE',fontsize=42,color=color1)
ax[0].set_xticks(hidden_size)
ax[0].set_yticks(np.arange(0.33,0.46, 0.04))
ax[0].tick_params(axis='x', labelsize=42)
ax[0].tick_params(axis='y',labelcolor=color1,labelsize=42)
# ax[0].grid(linestyle='dashed')
ax0_ = ax[0].twinx()
line2,=ax0_.plot(hidden_size, ETTm1_hd_mapes, markersize='20',color=color2, linestyle='-',linewidth=6, marker='o',label='MAPE', zorder=1)
ax0_.set_ylabel('MAPE',fontsize=42,color=color2)
ax0_.set_yticks(np.arange(2.69, 3, 0.09))
ax0_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[0].set_xlabel('h',fontsize=70)
# ax[0].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# layers
line3,=ax[1].plot(layers, ETTm1_layer_rmses, markersize='20', color=color1, linestyle='-', linewidth=6, marker='s', label='RMSE',zorder=1)
ax[1].set_xlabel('Num of layers',fontsize=42)
ax[1].set_ylabel('RMSE',fontsize=42,color=color1)
ax[1].set_xticks(layers)
ax[1].set_yticks(np.arange(0.33,0.50, 0.05))
ax[1].tick_params(axis='x', labelsize=42)
ax[1].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[1].grid(linestyle='dashed')
ax1_ = ax[1].twinx()
line4,=ax1_.plot(layers, ETTm1_layer_mapes, markersize='20', color=color2, linestyle='-', linewidth=6,marker='o', label='MAPE',zorder=1)
ax1_.set_ylabel('MAPE',fontsize=42,color=color2)
ax1_.set_yticks(np.arange(2.65, 3.4, 0.23))
ax1_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[1].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# beta end
line5,=ax[2].plot(beta_end, ETTm1_beta_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[2].set_xlabel('Maximum noise level',fontsize=42)
ax[2].set_ylabel('RMSE',fontsize=42,color=color1)
ax[2].set_xticks(beta_end)
ax[2].set_yticks(np.arange(0.33,0.46, 0.04))
ax[2].tick_params(axis='x', labelsize=42)
ax[2].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[2].grid(linestyle='dashed')
ax2_=ax[2].twinx()
line6,=ax2_.plot(beta_end, ETTm1_beta_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax2_.set_ylabel('MAPE',fontsize=42,color=color2)
ax2_.set_yticks(np.arange(2.69, 3.10, 0.11))
ax2_.tick_params(axis='y',labelcolor=color2, labelsize=42)

# loss weight
xticks=[1,2,3,4,5]
line7,=ax[3].plot(xticks, ETTm1_lw_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[3].set_xlabel('Loss weight',fontsize=42)
ax[3].set_ylabel('RMSE',fontsize=42,color=color1)
# ax[3].set_xticks(loss_weights)
ax[3].set_xticks([1,2,3,4,5],loss_weights)
# ax[3].xaxis.set_ticklabels(loss_weights)
ax[3].set_yticks(np.arange(0.34,0.44, 0.03))
ax[3].tick_params(axis='x', labelsize=42)
ax[3].tick_params(axis='y',labelcolor=color1, labelsize=42)
ax3_=ax[3].twinx()
line8,=ax3_.plot(xticks, ETTm1_lw_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax3_.set_ylabel('MAPE',fontsize=42,color=color2)
ax3_.set_yticks(np.arange(2.69, 3.0, 0.1))
ax3_.tick_params(axis='y',labelcolor=color2, labelsize=42)

ax[0].legend(handles=[line1, line2], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[1].legend(handles=[line3, line4], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[2].legend(handles=[line5, line6], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[3].legend(handles=[line7, line8], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[3].grid()

plt.tight_layout()
plt.savefig('../img/hyperparameter_study_ETTm1_point.pdf',dpi=300,bbox_inches='tight')
plt.savefig('../img/hyperparameter_study_ETTm1_point.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# Block Missing on ETTm1

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib

matplotlib.rcParams['pdf.fonttype']=42
matplotlib.rcParams['ps.fonttype']=42
plt.rcParams['font.sans-serif'] = ['Times New Roman']

# block missing
hidden_size=[16,32,64,128]
ETTm1_hd_maes=[0.648,0.589,0.583,0.616]
ETTm1_hd_rmses=[2.451,2.522,2.507,2.772]
ETTm1_hd_mapes=[8.422,7.663,7.575,8.013]
layers=[1,2,3,4]
ETTm1_layer_maes=[0.693,0.661,0.602,0.583]
ETTm1_layer_rmses=[2.594,2.596,2.572,2.507]
ETTm1_layer_mapes=[9.004,8.599,7.823,7.575]
beta_end=[0.1,0.2,0.3,0.4]
ETTm1_beta_maes=[0.652,0.583,0.682,0.672]
ETTm1_beta_rmses=[2.628,2.507,2.766,2.742]
ETTm1_beta_mapes=[8.481,7.575,8.866,8.742]
loss_weights=[0.5,1,2,5,10]
ETTm1_lw_maes=[0.662,0.65,0.633,0.583,0.64]
ETTm1_lw_rmses=[2.695,2.669,2.712,2.507,2.722]
ETTm1_lw_mapes=[8.614,8.448,8.225,7.575,8.324]


fig, ax = plt.subplots(1,4,figsize=(34,6))

color1='#0076B9'
color2='#FF8C00'

# hidden dimension
line1,=ax[0].plot(hidden_size, ETTm1_hd_rmses, markersize='20',color=color1, linestyle='-',linewidth=6, marker='s',label='RMSE', zorder=1)
ax[0].set_xlabel('Size of hidden dimension',fontsize=42)
ax[0].set_ylabel('RMSE',fontsize=42,color=color1)
ax[0].set_xticks(hidden_size)
ax[0].set_yticks(np.arange(2.40,3.00, 0.19))
ax[0].tick_params(axis='x', labelsize=42)
ax[0].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[0].grid(linestyle='dashed')
ax0_ = ax[0].twinx()
line2,=ax0_.plot(hidden_size, ETTm1_hd_mapes, markersize='20',color=color2, linestyle='-',linewidth=6, marker='o',label='MAPE', zorder=1)
ax0_.set_ylabel('MAPE',fontsize=42,color=color2)
ax0_.set_yticks(np.arange(7.42, 8.90, 0.43))
ax0_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[0].set_xlabel('h',fontsize=70)
# ax[0].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# layers
line3,=ax[1].plot(layers, ETTm1_layer_rmses, markersize='20', color=color1, linestyle='-', linewidth=6, marker='s', label='RMSE',zorder=1)
ax[1].set_xlabel('Num of layers',fontsize=42)
ax[1].set_ylabel('RMSE',fontsize=42,color=color1)
ax[1].set_xticks(layers)
ax[1].set_yticks(np.arange(2.40,2.90, 0.14))
ax[1].tick_params(axis='x', labelsize=42)
ax[1].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[1].grid(linestyle='dashed')
ax1_ = ax[1].twinx()
line4,=ax1_.plot(layers, ETTm1_layer_mapes, markersize='20', color=color2, linestyle='-', linewidth=6,marker='o', label='MAPE',zorder=1)
ax1_.set_ylabel('MAPE',fontsize=42,color=color2)
ax1_.set_yticks(np.arange(7.42, 9.50, 0.67))
ax1_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[1].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# beta end
line5,=ax[2].plot(beta_end, ETTm1_beta_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[2].set_xlabel('Maximum noise level',fontsize=42)
ax[2].set_ylabel('RMSE',fontsize=42,color=color1)
ax[2].set_xticks(beta_end)
ax[2].set_yticks(np.arange(2.40,3.2, 0.22))
ax[2].tick_params(axis='x', labelsize=42)
ax[2].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[2].grid(linestyle='dashed')
ax2_=ax[2].twinx()
line6,=ax2_.plot(beta_end, ETTm1_beta_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax2_.set_ylabel('MAPE',fontsize=42,color=color2)
ax2_.set_yticks(np.arange(7.42, 9.5, 0.6))
ax2_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[2].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),handlelength=1.5,frameon=False)

# loss weight
xticks=[1,2,3,4,5]
line7,=ax[3].plot(xticks, ETTm1_lw_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[3].set_xlabel('Loss weight',fontsize=42)
ax[3].set_ylabel('RMSE',fontsize=42,color=color1)
# ax[3].set_xticks(loss_weights)
ax[3].set_xticks([1,2,3,4,5],loss_weights)
# ax[3].xaxis.set_ticklabels(loss_weights)
ax[3].set_yticks(np.arange(2.49,2.83, 0.11))
ax[3].tick_params(axis='x', labelsize=42)
ax[3].tick_params(axis='y',labelcolor=color1, labelsize=42)
ax3_=ax[3].twinx()
line8,=ax3_.plot(xticks, ETTm1_lw_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax3_.set_ylabel('MAPE',fontsize=42,color=color2)
ax3_.set_yticks(np.arange(7.40, 8.94, 0.51))
ax3_.tick_params(axis='y',labelcolor=color2, labelsize=42)

ax[0].legend(handles=[line1, line2], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[1].legend(handles=[line3, line4], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[2].legend(handles=[line5, line6], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[3].legend(handles=[line7, line8], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[3].grid()

plt.tight_layout()
plt.savefig('../img/hyperparameter_study_ETTm1_block.pdf',dpi=300,bbox_inches='tight')
plt.savefig('../img/hyperparameter_study_ETTm1_block.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# point missing on Weather

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib

matplotlib.rcParams['pdf.fonttype']=42
matplotlib.rcParams['ps.fonttype']=42
plt.rcParams['font.sans-serif'] = ['Times New Roman']

# point missing
hidden_size=[16,32,64,128]
Weather_hd_maes=[2.175,2.079,1.935,1.937]
Weather_hd_rmses=[16.969,16.958,15.992,16.204]
Weather_hd_mapes=[1.29,1.233,1.147,1.148]
layers=[1,2,3,4]
Weather_layer_maes=[2.266,2.068,1.985,1.935]
Weather_layer_rmses=[17.425,16.413,16.254,15.992]
Weather_layer_mapes=[1.344,1.226,1.177,1.147]
beta_end=[0.1,0.2,0.3,0.4]
Weather_beta_maes=[2.024,1.935,1.942,1.97]
Weather_beta_rmses=[17.476,15.992,16.153,16.433]
Weather_beta_mapes=[1.2,1.147,1.151,1.168]
loss_weights=[0.5,1,2,5,10]
Weather_lw_maes=[1.968,1.947,1.936,1.935,1.952]
Weather_lw_rmses=[16.176,16.088,16.039,15.992,16.120]
Weather_lw_mapes=[1.167,1.154,1.148,1.147,1.158]

fig, ax = plt.subplots(1,4,figsize=(34,6))

color1='#0076B9'
color2='#FF8C00'

# hidden dimension
line1,=ax[0].plot(hidden_size, Weather_hd_rmses, markersize='20',color=color1, linestyle='-',linewidth=6, marker='s',label='RMSE', zorder=1)
ax[0].set_xlabel('Size of hidden dimension',fontsize=42)
ax[0].set_ylabel('RMSE',fontsize=42,color=color1)
ax[0].set_xticks(hidden_size)
ax[0].set_yticks(np.arange(15.82,17.5,0.5))
ax[0].tick_params(axis='x', labelsize=42)
ax[0].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[0].grid(linestyle='dashed')
ax0_ = ax[0].twinx()
line2,=ax0_.plot(hidden_size, Weather_hd_mapes, markersize='20',color=color2, linestyle='-',linewidth=6, marker='o',label='MAPE', zorder=1)
ax0_.set_ylabel('MAPE',fontsize=42,color=color2)
ax0_.set_yticks(np.arange(1.10,1.4,0.08))
ax0_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[0].set_xlabel('h',fontsize=70)
# ax[0].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# layers
line3,=ax[1].plot(layers, Weather_layer_rmses, markersize='20', color=color1, linestyle='-', linewidth=6, marker='s', label='RMSE',zorder=1)
ax[1].set_xlabel('Num of layers',fontsize=42)
ax[1].set_ylabel('RMSE',fontsize=42,color=color1)
ax[1].set_xticks(layers)
ax[1].set_yticks(np.arange(15.80,18.00,0.72))
ax[1].tick_params(axis='x', labelsize=42)
ax[1].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[1].grid(linestyle='dashed')
ax1_ = ax[1].twinx()
line4,=ax1_.plot(layers, Weather_layer_mapes, markersize='20', color=color2, linestyle='-', linewidth=6,marker='o', label='MAPE',zorder=1)
ax1_.set_ylabel('MAPE',fontsize=42,color=color2)
ax1_.set_yticks(np.arange(1.10,1.50,0.11))
ax1_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[1].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# beta end
line5,=ax[2].plot(beta_end, Weather_beta_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[2].set_xlabel('Maximum noise level',fontsize=42)
ax[2].set_ylabel('RMSE',fontsize=42,color=color1)
ax[2].set_xticks(beta_end)
ax[2].set_yticks(np.arange(15.82,18.10,0.75))
ax[2].tick_params(axis='x', labelsize=42)
ax[2].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[2].grid(linestyle='dashed')
ax2_=ax[2].twinx()
line6,=ax2_.plot(beta_end, Weather_beta_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax2_.set_ylabel('MAPE',fontsize=42,color=color2)
ax2_.set_yticks(np.arange(1.12,1.25,0.04))
ax2_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[2].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),handlelength=1.5,frameon=False)

# loss weight
xticks=[1,2,3,4,5]
line7,=ax[3].plot(xticks, Weather_lw_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[3].set_xlabel('Loss weight',fontsize=42)
ax[3].set_ylabel('RMSE',fontsize=42,color=color1)
# ax[3].set_xticks(loss_weights)
ax[3].set_xticks([1,2,3,4,5],loss_weights)
# ax[3].xaxis.set_ticklabels(loss_weights)
ax[3].set_yticks(np.arange(15.95,16.30, 0.11))
ax[3].tick_params(axis='x', labelsize=42)
ax[3].tick_params(axis='y',labelcolor=color1, labelsize=42)
ax3_=ax[3].twinx()
line8,=ax3_.plot(xticks, Weather_lw_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax3_.set_ylabel('MAPE',fontsize=42,color=color2)
ax3_.set_yticks(np.arange(1.10, 1.20, 0.03))
ax3_.tick_params(axis='y',labelcolor=color2, labelsize=42)

ax[0].legend(handles=[line1, line2], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[1].legend(handles=[line3, line4], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[2].legend(handles=[line5, line6], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[3].legend(handles=[line7, line8], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[3].grid()

plt.tight_layout()
plt.savefig('../img/hyperparameter_study_Weather_point.pdf',dpi=300,bbox_inches='tight')
plt.savefig('../img/hyperparameter_study_Weather_point.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# block missing on Weather

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib

matplotlib.rcParams['pdf.fonttype']=42
matplotlib.rcParams['ps.fonttype']=42
plt.rcParams['font.sans-serif'] = ['Times New Roman']

# block missing
hidden_size=[16,32,64,128]
Weather_hd_maes=[3.868,3.223,2.992,2.868]
Weather_hd_rmses=[23.165,21.435,20.836,20.170]
Weather_hd_mapes=[2.238,1.865,1.731,1.659]
layers=[1,2,3,4]
Weather_layer_maes=[3.841,3.264,3.056,2.992]
Weather_layer_rmses=[23.006,21.66,21.135,20.836]
Weather_layer_mapes=[2.223,1.888,1.768,1.731]
beta_end=[0.1,0.2,0.3,0.4]
Weather_beta_maes=[3.212,2.992,3.035,3.108]
Weather_beta_rmses=[23.149,20.836,21.118,21.321]
Weather_beta_mapes=[1.859,1.731,1.756,1.799]
loss_weights=[0.5,1,2,5,10]
Weather_lw_maes=[3.015,2.992,3.006,3.078,3.064]
Weather_lw_rmses=[21.222,20.836,21.264,21.312,21.419]
Weather_lw_mapes=[1.744,1.731,1.739,1.781,1.773]

fig, ax = plt.subplots(1,4,figsize=(34,6))

color1='#0076B9'
color2='#FF8C00'

# hidden dimension
line1,=ax[0].plot(hidden_size, Weather_hd_rmses, markersize='20',color=color1, linestyle='-',linewidth=6, marker='s',label='RMSE', zorder=1)
ax[0].set_xlabel('Size of hidden dimension',fontsize=42)
ax[0].set_ylabel('RMSE',fontsize=42,color=color1)
ax[0].set_xticks(hidden_size)
ax[0].set_yticks(np.arange(20.00,25.0,1.36))
ax[0].tick_params(axis='x', labelsize=42)
ax[0].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[0].grid(linestyle='dashed')
ax0_ = ax[0].twinx()
line2,=ax0_.plot(hidden_size, Weather_hd_mapes, markersize='20',color=color2, linestyle='-',linewidth=6, marker='o',label='MAPE', zorder=1)
ax0_.set_ylabel('MAPE',fontsize=42,color=color2)
ax0_.set_yticks(np.arange(1.60,2.52,0.29))
ax0_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[0].set_xlabel('h',fontsize=70)
# ax[0].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# layers
line3,=ax[1].plot(layers, Weather_layer_rmses, markersize='20', color=color1, linestyle='-', linewidth=6, marker='s', label='RMSE',zorder=1)
ax[1].set_xlabel('Num of layers',fontsize=42)
ax[1].set_ylabel('RMSE',fontsize=42,color=color1)
ax[1].set_xticks(layers)
ax[1].set_yticks(np.arange(20.40,25.0,1.22))
ax[1].tick_params(axis='x', labelsize=42)
ax[1].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[1].grid(linestyle='dashed')
ax1_ = ax[1].twinx()
line4,=ax1_.plot(layers, Weather_layer_mapes, markersize='20', color=color2, linestyle='-', linewidth=6,marker='o', label='MAPE',zorder=1)
ax1_.set_ylabel('MAPE',fontsize=42,color=color2)
ax1_.set_yticks(np.arange(1.60,2.52,0.27))
ax1_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[1].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# beta end
line5,=ax[2].plot(beta_end, Weather_beta_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[2].set_xlabel('Maximum noise level',fontsize=42)
ax[2].set_ylabel('RMSE',fontsize=42,color=color1)
ax[2].set_xticks(beta_end)
ax[2].set_yticks(np.arange(20.20,25.00,1.32))
ax[2].tick_params(axis='x', labelsize=42)
ax[2].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[2].grid(linestyle='dashed')
ax2_=ax[2].twinx()
line6,=ax2_.plot(beta_end, Weather_beta_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax2_.set_ylabel('MAPE',fontsize=42,color=color2)
ax2_.set_yticks(np.arange(1.60,2.00,0.13))
ax2_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[2].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),handlelength=1.5,frameon=False)

# loss weight
xticks=[1,2,3,4,5]
line7,=ax[3].plot(xticks, Weather_lw_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[3].set_xlabel('Loss weight',fontsize=42)
ax[3].set_ylabel('RMSE',fontsize=42,color=color1)
# ax[3].set_xticks(loss_weights)
ax[3].set_xticks([1,2,3,4,5],loss_weights)
# ax[3].xaxis.set_ticklabels(loss_weights)
ax[3].set_yticks(np.arange(20.80,21.70, 0.29))
ax[3].tick_params(axis='x', labelsize=42)
ax[3].tick_params(axis='y',labelcolor=color1, labelsize=42)
ax3_=ax[3].twinx()
line8,=ax3_.plot(xticks, Weather_lw_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax3_.set_ylabel('MAPE',fontsize=42,color=color2)
ax3_.set_yticks(np.arange(1.72, 1.82, 0.03))
ax3_.tick_params(axis='y',labelcolor=color2, labelsize=42)

ax[0].legend(handles=[line1, line2], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[1].legend(handles=[line3, line4], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[2].legend(handles=[line5, line6], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[3].legend(handles=[line7, line8], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[3].grid()


plt.tight_layout()
plt.savefig('../img/hyperparameter_study_Weather_block.pdf',dpi=300,bbox_inches='tight')
plt.savefig('../img/hyperparameter_study_Weather_block.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# point missing on METR-LA

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib

matplotlib.rcParams['pdf.fonttype']=42
matplotlib.rcParams['ps.fonttype']=42
plt.rcParams['font.sans-serif'] = ['Times New Roman']

# point missing
hidden_size=[16,32,64,128]
METRLA_hd_maes=[1.986,1.939,1.639,1.663]
METRLA_hd_rmses=[3.599,3.516,3.040,3.082]
METRLA_hd_mapes=[3.468,3.386,2.861,2.903]
layers=[1,2,3,4]
METRLA_layer_maes=[1.97,1.876,1.84,1.639]
METRLA_layer_rmses=[3.569,3.452,3.416,3.040]
METRLA_layer_mapes=[3.44,3.276,3.212,2.861]
beta_end=[0.1,0.2,0.3,0.4]
METRLA_beta_maes=[1.74,1.639,1.863,1.867]
METRLA_beta_rmses=[3.243,3.040,3.419,3.454]
METRLA_beta_mapes=[3.038,2.861,3.253,3.259]
loss_weights=[0.5,1,2,5,10]
METRLA_lw_maes=[1.693,1.686,1.717,1.639,1.762]
METRLA_lw_rmses=[3.152,3.145,3.21,3.040,3.291]
METRLA_lw_mapes=[2.957,2.943,2.997,2.861,3.076]

fig, ax = plt.subplots(1,4,figsize=(34,6))

color1='#0076B9'
color2='#FF8C00'

# hidden dimension
line1,=ax[0].plot(hidden_size, METRLA_hd_rmses, markersize='20',color=color1, linestyle='-',linewidth=6, marker='s',label='RMSE', zorder=1)
ax[0].set_xlabel('Size of hidden dimension',fontsize=42)
ax[0].set_ylabel('RMSE',fontsize=42,color=color1)
ax[0].set_xticks(hidden_size)
ax[0].set_yticks(np.arange(2.90,3.89,0.31))
ax[0].tick_params(axis='x', labelsize=42)
ax[0].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[0].grid(linestyle='dashed')
ax0_ = ax[0].twinx()
line2,=ax0_.plot(hidden_size, METRLA_hd_mapes, markersize='20',color=color2, linestyle='-',linewidth=6, marker='o',label='MAPE', zorder=1)
ax0_.set_ylabel('MAPE',fontsize=42,color=color2)
ax0_.set_yticks(np.arange(2.80,3.69,0.29))
ax0_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[0].set_xlabel('h',fontsize=70)
# ax[0].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# layers
line3,=ax[1].plot(layers, METRLA_layer_rmses, markersize='20', color=color1, linestyle='-', linewidth=6, marker='s', label='RMSE',zorder=1)
ax[1].set_xlabel('Num of layers',fontsize=42)
ax[1].set_ylabel('RMSE',fontsize=42,color=color1)
ax[1].set_xticks(layers)
ax[1].set_yticks(np.arange(2.90,3.85,0.29))
ax[1].tick_params(axis='x', labelsize=42)
ax[1].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[1].grid(linestyle='dashed')
ax1_ = ax[1].twinx()
line4,=ax1_.plot(layers, METRLA_layer_mapes, markersize='20', color=color2, linestyle='-', linewidth=6,marker='o', label='MAPE',zorder=1)
ax1_.set_ylabel('MAPE',fontsize=42,color=color2)
ax1_.set_yticks(np.arange(2.80,3.72,0.28))
ax1_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[1].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# beta end
line5,=ax[2].plot(beta_end, METRLA_beta_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[2].set_xlabel('Maximum noise level',fontsize=42)
ax[2].set_ylabel('RMSE',fontsize=42,color=color1)
ax[2].set_xticks(beta_end)
ax[2].set_yticks(np.arange(2.90,3.80,0.28))
ax[2].tick_params(axis='x', labelsize=42)
ax[2].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[2].grid(linestyle='dashed')
ax2_=ax[2].twinx()
line6,=ax2_.plot(beta_end, METRLA_beta_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax2_.set_ylabel('MAPE',fontsize=42,color=color2)
ax2_.set_yticks(np.arange(2.70,3.50,0.24))
ax2_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[2].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),handlelength=1.5,frameon=False)

# loss weight
xticks=[1,2,3,4,5]
line7,=ax[3].plot(xticks, METRLA_lw_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[3].set_xlabel('Loss weight',fontsize=42)
ax[3].set_ylabel('RMSE',fontsize=42,color=color1)
# ax[3].set_xticks(loss_weights)
ax[3].set_xticks([1,2,3,4,5],loss_weights)
# ax[3].xaxis.set_ticklabels(loss_weights)
ax[3].set_yticks(np.arange(3.00,3.50,0.14))
ax[3].tick_params(axis='x', labelsize=42)
ax[3].tick_params(axis='y',labelcolor=color1, labelsize=42)
ax3_=ax[3].twinx()
line8,=ax3_.plot(xticks, METRLA_lw_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax3_.set_ylabel('MAPE',fontsize=42,color=color2)
ax3_.set_yticks(np.arange(2.85,3.20,0.11))
ax3_.tick_params(axis='y',labelcolor=color2, labelsize=42)

ax[0].legend(handles=[line1, line2], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[1].legend(handles=[line3, line4], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[2].legend(handles=[line5, line6], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[3].legend(handles=[line7, line8], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[3].grid()

plt.tight_layout()
plt.savefig('../img/hyperparameter_study_METRLA_point.pdf',dpi=300,bbox_inches='tight')
plt.savefig('../img/hyperparameter_study_METRLA_point.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# block missing on METR-LA

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib

matplotlib.rcParams['pdf.fonttype']=42
matplotlib.rcParams['ps.fonttype']=42
plt.rcParams['font.sans-serif'] = ['Times New Roman']

# point missing
hidden_size=[16,32,64,128]
METRLA_hd_maes=[2.789,2.682,1.982,2.033]
METRLA_hd_rmses=[5.774,5.580,3.914,4.050]
METRLA_hd_mapes=[4.871,4.684,3.462,3.551]
layers=[1,2,3,4]
METRLA_layer_maes=[2.744,2.566,2.287,1.982]
METRLA_layer_rmses=[5.574,5.401,4.651,3.914]
METRLA_layer_mapes=[4.792,4.482,3.994,3.462]
beta_end=[0.1,0.2,0.3,0.4]
METRLA_beta_maes=[2.202,1.982,2.261,2.248]
METRLA_beta_rmses=[4.431,3.914,4.541,4.51]
METRLA_beta_mapes=[3.846,3.462,3.949,3.927]
loss_weights=[0.5,1,2,5,10]
METRLA_lw_maes=[2.050,2.214,2.071,1.982,2.207]
METRLA_lw_rmses=[4.039,4.526,4.091,3.914,4.382]
METRLA_lw_mapes=[3.581,3.868,3.617,3.462,3.855]

fig, ax = plt.subplots(1,4,figsize=(34,6))

color1='#0076B9'
color2='#FF8C00'

# hidden dimension
line1,=ax[0].plot(hidden_size, METRLA_hd_rmses, markersize='20',color=color1, linestyle='-',linewidth=6, marker='s',label='RMSE', zorder=1)
ax[0].set_xlabel('Size of hidden dimension',fontsize=42)
ax[0].set_ylabel('RMSE',fontsize=42,color=color1)
ax[0].set_xticks(hidden_size)
ax[0].set_yticks(np.arange(3.60,6.70,1.02))
ax[0].tick_params(axis='x', labelsize=42)
ax[0].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[0].grid(linestyle='dashed')
ax0_ = ax[0].twinx()
line2,=ax0_.plot(hidden_size, METRLA_hd_mapes, markersize='20',color=color2, linestyle='-',linewidth=6, marker='o',label='MAPE', zorder=1)
ax0_.set_ylabel('MAPE',fontsize=42,color=color2)
ax0_.set_yticks(np.arange(3.40,5.40,0.63))
ax0_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[0].set_xlabel('h',fontsize=70)
# ax[0].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# layers
line3,=ax[1].plot(layers, METRLA_layer_rmses, markersize='20', color=color1, linestyle='-', linewidth=6, marker='s', label='RMSE',zorder=1)
ax[1].set_xlabel('Num of layers',fontsize=42)
ax[1].set_ylabel('RMSE',fontsize=42,color=color1)
ax[1].set_xticks(layers)
ax[1].set_yticks(np.arange(3.60,6.20,0.84))
ax[1].tick_params(axis='x',labelsize=42)
ax[1].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[1].grid(linestyle='dashed')
ax1_ = ax[1].twinx()
line4,=ax1_.plot(layers, METRLA_layer_mapes, markersize='20', color=color2, linestyle='-', linewidth=6,marker='o', label='MAPE',zorder=1)
ax1_.set_ylabel('MAPE',fontsize=42,color=color2)
ax1_.set_yticks(np.arange(3.30,5.30,0.63))
ax1_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[1].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),edgecolor='black',handlelength=1.5,frameon=False)

# beta end
line5,=ax[2].plot(beta_end, METRLA_beta_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[2].set_xlabel('Maximum noise level',fontsize=42)
ax[2].set_ylabel('RMSE',fontsize=42,color=color1)
ax[2].set_xticks(beta_end)
ax[2].set_yticks(np.arange(3.80,4.90,0.34))
ax[2].tick_params(axis='x', labelsize=42)
ax[2].tick_params(axis='y',labelcolor=color1, labelsize=42)
# ax[2].grid(linestyle='dashed')
ax2_=ax[2].twinx()
line6,=ax2_.plot(beta_end, METRLA_beta_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax2_.set_ylabel('MAPE',fontsize=42,color=color2)
ax2_.set_yticks(np.arange(3.40,4.90,0.44))
ax2_.tick_params(axis='y',labelcolor=color2, labelsize=42)
# ax[2].legend(loc='upper center',fontsize=65, bbox_to_anchor=(0.5, 1),handlelength=1.5,frameon=False)

# loss weight
xticks=[1,2,3,4,5]
line7,=ax[3].plot(xticks, METRLA_lw_rmses, markersize='20',color=color1, linestyle='-', linewidth=6,marker='s',label='RMSE',zorder=1)
ax[3].set_xlabel('Loss weight',fontsize=42)
ax[3].set_ylabel('RMSE',fontsize=42,color=color1)
# ax[3].set_xticks(loss_weights)
ax[3].set_xticks([1,2,3,4,5],loss_weights)
# ax[3].xaxis.set_ticklabels(loss_weights)
ax[3].set_yticks(np.arange(3.88,4.84,0.29))
ax[3].tick_params(axis='x', labelsize=42)
ax[3].tick_params(axis='y',labelcolor=color1, labelsize=42)
ax3_=ax[3].twinx()
line8,=ax3_.plot(xticks, METRLA_lw_mapes, markersize='20',color=color2, linestyle='-', linewidth=6,marker='o',label='MAPE',zorder=1)
ax3_.set_ylabel('MAPE',fontsize=42,color=color2)
ax3_.set_yticks(np.arange(3.42,4.05,0.19))
ax3_.tick_params(axis='y',labelcolor=color2, labelsize=42)

ax[0].legend(handles=[line1, line2], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[1].legend(handles=[line3, line4], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[2].legend(handles=[line5, line6], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[3].legend(handles=[line7, line8], loc='upper center',fontsize=30, handlelength=1,ncol=2)
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[3].grid()


plt.tight_layout()
plt.savefig('../img/hyperparameter_study_METRLA_block.pdf',dpi=300,bbox_inches='tight')
plt.savefig('../img/hyperparameter_study_METRLA_block.svg',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped
